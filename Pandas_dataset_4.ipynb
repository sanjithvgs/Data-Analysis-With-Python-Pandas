# %% [markdown]
# https://www.kaggle.com/datasets/wenruliu/adult-income-dataset

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dat=pd.read_csv('/content/gdrive/MyDrive/Dataset/adult.csv')

# %%
dat
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
  dat.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
dat.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
dat.shape
# Out:
# (48842, 15)

# %%
dat.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
 dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # **Fetch Random sample from dataset(50%)**

# %%
dat.sample(frac=0.50)       #give random dataset of 50%
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 22980   55           Private  204751       HS-grad                9
# 27290   31           Private  124827       HS-grad                9
# 1540    40         State-gov  285000     Bachelors               13
# 28456   21                 ?  479482  Some-college               10
# 491     27           Private  203160     Bachelors               13
# ...    ...               ...     ...           ...              ...
# 31720   33           Private  118710     Assoc-voc               11
# 2654    78  Self-emp-not-inc  152148       7th-8th                4
# 37807   37           Private  236328          10th                6
# 24629   51           Private  123703       HS-grad                9
# 11254   37           Private  175232     Bachelors               13
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
dat.sample(frac=0.50,random_state=112)       #give random dataset of same for every execute
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 19313   47           Private  125892  Some-college               10
# 32443   35  Self-emp-not-inc  454915           9th                5
# 26878   35         State-gov   80771       Masters               14
# 2465    24           Private  403107     Preschool                1
# 13911   29           Private  254450     Assoc-voc               11
# ...    ...               ...     ...           ...              ...
# 12639   49           Private  207772       HS-grad                9
# 28172   43           Private  177083  Some-college               10
# 13678   28           Private  359049       HS-grad                9
# 21985   30  Self-emp-not-inc  188798       HS-grad                9
# 34825   52           Private  186272       HS-grad                9
#
#            marital-status      occupation   relationship   race  gender  \
# 19313  Married-civ-spouse    Craft-repair        Husband  White    Male
# ...

# %%
dat.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
sns.heatmap(dat.isnull())

# %% [markdown]
# # **Data cleaning [Replace '?' with NaN]**

# %%
sns.heatmap(dat.isin(['?']))

# %%
dat.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
dat.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
dat['workclass']=dat['workclass'].replace('?',np.nan)
dat['occupation']=dat['occupation'].replace('?',np.nan)
dat['native-country']=dat['native-country'].replace('?',np.nan)

# %%
dat.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
dat.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %% [markdown]
# # **Drop all missing values**

# %%
dat.isnull().sum()*100/len(dat)
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
dat.dropna(how='any',inplace=True)

# %%
dat.isnull().sum()*100/len(dat)
# Out:
# age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %% [markdown]
# # **Drop Duplicate values**

# %%
dup=dat.duplicated().any()

# %%
dup
# Out:
# True

# %%
dat=dat.drop_duplicates()

# %%
dat.shape
# Out:
# (45175, 15)

# %% [markdown]
# # **Get Overall Statistics About The Dataframe**

# %%
dat.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %% [markdown]
# # **Drop The Columns education-num, capital-gain and capital-loss**

# %%
dat.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
dat=dat.drop(['educational-num','capital-gain','capital-loss'],axis=1)

# %%
dat.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %% [markdown]
# # **Univariate Analysis**

# %% [markdown]
# **What Is The Distribution of Age Column?**

# %%
dat.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
dat['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
dat['age'].hist()

# %% [markdown]
# **Find Total Number of Persons Having Age Between 17 To 48
# (Inclusive) Using Between**

# %%
dat['age']
# Out:
# 0        25
# 1        38
# 2        28
# 3        44
# 5        34
#          ..
# 48837    27
# 48838    40
# 48839    58
# 48840    22
# 48841    52
# Name: age, Length: 45175, dtype: int64

# %%
dat[dat['age'].between(17,48)]
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       25    Private  226802          11th       Never-married
# 1       38    Private   89814       HS-grad  Married-civ-spouse
# 2       28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44    Private  160323  Some-college  Married-civ-spouse
# 5       34    Private  198693          10th       Never-married
# ...    ...        ...     ...           ...                 ...
# 48834   32    Private  116138       Masters       Never-married
# 48836   22    Private  310152  Some-college       Never-married
# 48837   27    Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40    Private  154374       HS-grad  Married-civ-spouse
# 48840   22    Private  201490       HS-grad       Never-married
#
#               occupation   relationship                race  gender  \
# 0      Machine-op-inspct      Own-child               Black    Male
# ...

# %%
sum(dat['age'].between(17,48))
# Out:
# 34858

# %%
sum((dat['age']>=17) & (dat['age']<=48))
# Out:
# 34858

# %% [markdown]
# **What is The Distribution of Workclass Column?**

# %%
dat.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
dat['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45175, dtype: object

# %%
plt.figure(figsize=(10,5))          #to set width and height of below figure
dat['workclass'].hist()

# %% [markdown]
# **How Many Persons Having Bachelors or Masters Degree?**

# %%
sum((dat['education']=='Bachelors') | (dat['education']=='Masters'))
# Out:
# 10072

# %%
dat[(dat['education']=='Bachelors') | (dat['education']=='Masters')]
# Out:
#        age    workclass  fnlwgt  education      marital-status  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# 24      25      Private  205947  Bachelors  Married-civ-spouse
# ...    ...          ...     ...        ...                 ...
# 48817   34      Private  160216  Bachelors       Never-married
# 48819   38      Private  139180  Bachelors            Divorced
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# ...

# %% [markdown]
# # **Bivariate Analysis**

# %%
dat.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
sns.boxplot(x='income',y='age',data=dat)

# %% [markdown]
# **Replace Salary Values ['<=50K’, '">50K’] With 0 and 1**

# %%
 dat['income']
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 5        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 45175, dtype: object

# %%
sns.countplot('income',data=dat)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def salary(sal):
  if sal=='<=50K':
    return 0
  return 1

# %%
dat['Analog_income']=dat['income'].apply(salary)

# %%
dat
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %%
dat['Analog_income'].replace([0,1],['Bad','Good'],inplace=True)

# %%
dat['Analog_income'].replace(['Bad','Good'],[0,1],inplace=True)

# %%
dat
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %% [markdown]
#  **Which Workclass Getting The Highest Salary?**

# %%
dat.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Analog_income'],
#       dtype='object')

# %%
dat['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45175, dtype: object

# %%
dat.groupby('workclass')['Analog_income'].mean().sort_values(ascending=False).head(1)
# Out:
# workclass
# Self-emp-inc    1.554407
# Name: Analog_income, dtype: float64

# %% [markdown]
# **Covert workclass Columns Datatype To Category Datatype**

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  object
#  12  Analog_income   45175 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 5.8+ MB

# %%
dat['workclass']=dat['workclass'].astype('category')

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  category
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  object
#  12  Analog_income   45175 non-null  int64
# dtypes: category(1), int64(4), object(8)
# memory usage: 5.5+ MB
