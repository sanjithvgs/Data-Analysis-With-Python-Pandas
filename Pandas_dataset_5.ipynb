# %% [markdown]
# https://www.kaggle.com/competitions/titanic/data?select=train.csv

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dat=pd.read_csv('/content/gdrive/MyDrive/Dataset/train.csv')

# %%
dat
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Display Top 5 Rows of The Dataset**

# %%
dat.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # **Check the Last 3 Rows of The Dataset**

# %%
dat.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # **Find Shape of Our Dataset (Number of Rows & Number of Columns)**

# %%
dat.shape
# Out:
# (891, 12)

# %%
col=dat.shape[1]
row=dat.shape[0]
print('Columns:',col,'\n','Rows:',row)
# Out:
# Columns: 12
#  Rows: 891

# %% [markdown]
# # **Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement**

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # **Get Overall Statistics About The Dataframe**

# %%
dat.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dat.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# # **Data Filtering**

# %%
dat.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dat['Sex']=='male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
dat[dat['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
dat[dat['Sex']=='male']['Age']
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 883    28.0
# 884    25.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 577, dtype: float64

# %%
dat[(dat['Survived']==1) & (dat['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # **Check Null Values In The Dataset**

# %%
dat.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.heatmap(dat.isnull())

# %%
dat.isnull().sum(axis=1)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    2
# 889    0
# 890    1
# Length: 891, dtype: int64

# %%
miss_data=dat.isnull().sum()*100/len(dat)
miss_data
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# # **Drop the Column**

# %%
dat.drop('Cabin',axis=1,inplace=True)

# %%
dat.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# # **Handle Missing Values**

# %%
dat.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
dat['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
dat['Embarked'].mode()        #mode() show most frequent value in the column
# Out:
# 0    S
# dtype: object

# %%
dat['Embarked'].fillna('S',inplace=True)            #fillna will replace null value with given give (Here null value replace by 'S')

# %%
dat['Embarked'].isnull().sum()
# Out:
# 0

# %%
dat.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
dat['Age'].mean()
# Out:
# 29.69911764705882

# %%
dat['Age'].fillna(29,inplace=True)

# %%
dat.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # **Categorical Data Encoding**

# %%
dat.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
dat['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
dat['Gender']=dat['Sex'].map({'male':1,'female':2})

# %%
dat
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
var=dat['Sex'].map({'male':1,'female':2})

# %%
dat.insert(5,'Gender_New',var)

# %%
dat
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender_New  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                               Heikkinen, Miss. Laina  female           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %%
dat.drop('Gender',axis=1,inplace=True)

# %%
dat
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender_New  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                               Heikkinen, Miss. Laina  female           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %%
dat['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
pd.get_dummies(dat,columns=['Embarked'])        #Embarked_C	Embarked_Q	Embarked_S  [New columns created like this]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender_New  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                               Heikkinen, Miss. Laina  female           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %%
pd.get_dummies(dat,columns=['Embarked'],drop_first=True)     #Embarked_C	Embarked_Q	Embarked_S [First columns: Embarked_C dropped]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender_New  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                               Heikkinen, Miss. Laina  female           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %%
data=pd.get_dummies(dat,columns=['Embarked'],drop_first=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender_New  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                               Heikkinen, Miss. Laina  female           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %% [markdown]
# ## **What is Univariate Analysis?**

# %% [markdown]
# # 1. How Many People Survived And How Many Died?

# %%
dat['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(dat['Survived'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 2. How Many Passengers Were In First Class, Second Class, and Third Class?

# %%
dat.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
dat['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(dat['Pclass'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 3. Number of Male And Female Passengers

# %%
dat['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(dat['Sex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.hist(dat['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
sns.countplot(dat['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(dat['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Bivariate Analysis**

# %%
dat.columns      #'Survived' is Target (or) dependent variable   and other are independent varaible
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # 1. How Has Better Chance of Survival Male or Female?

# %%
sns.barplot(x='Sex',y='Survived',data=dat)

# %% [markdown]
# # 2.Which Passenger Class Has Better Chance of Survival (First, Second, Or Third Class)?

# %%
sns.barplot(x='Pclass',y='Survived',data=dat)

# %% [markdown]
# # **Feature Engineering**

# %%
dat.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
dat['Family_size']=dat['SibSp'] + dat['Parch']

# %%
dat.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Gender_New  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                             Heikkinen, Miss. Laina  female           2
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare Embarked  Family_size
# 0  22.0      1      0         A/5 21171   7.2500        S            1
# 1  38.0      1      0          PC 17599  71.2833        C            1
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S            0
# ...

# %%
dat['Fare_per_person']=dat['Fare']/(dat['Family_size']+1)

# %%
dat.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Gender_New  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                             Heikkinen, Miss. Laina  female           2
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare Embarked  Family_size  \
# 0  22.0      1      0         A/5 21171   7.2500        S            1
# 1  38.0      1      0          PC 17599  71.2833        C            1
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S            0
# ...
